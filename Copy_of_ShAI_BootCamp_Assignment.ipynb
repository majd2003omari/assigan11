# %% [markdown]
# <a href="https://colab.research.google.com/github/majd2003omari/assigan11/blob/main/Copy_of_ShAI_BootCamp_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #About Dataset
# salaries dataset generally provides information about the employees of an organization in relation to their compensation. It typically includes details such as how much each employee is paid (their salary), their job titles, the departments they work in, and possibly additional information like their level of experience, education, and employment history within the organization.

# %% [markdown]
# # Features
# - 'Id'
# - 'EmployeeName'
# - 'JobTitle'
# - 'BasePay'
# - 'OvertimePay'
# - 'OtherPay'
# - 'Benefits'
# - 'TotalPay' -> salary
# - 'TotalPayBenefits'
# - 'Year'
# - 'Notes'
# - 'Agency'
# - 'Status'

# %% [markdown]
# # Tasks
#
# 1. **Basic Data Exploration**: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.
#
# 2. **Descriptive Statistics**: Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.
#
# 3. **Data Cleaning**: Handle missing data by suitable method with explain why you use it.
#
# 4. **Basic Data Visualization**: Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.
#
# 5. **Grouped Analysis**: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.
#
# 6. **Simple Correlation Analysis**: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.
#
# 8. **Summary of Insights**: Write a brief report summarizing the findings and insights from the analyses.

# %% [markdown]
# # Very Important Note
# There is no fixed or singular solution for this assignment, so if anything is not clear, please do what you understand and provide an explanation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset
df = pd.read_csv('/content/Salaries.csv')
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# ...

# %%
### Basic Data Exploration:


# Identify the number of rows and columns
num_rows, num_columns = df.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 148654
# Number of columns: 13

# %%
# Determine the data types of each column
data_types = df.dtypes
print("\nData types of each column:")
print(data_types)
# Out:
# Data types of each column:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status              float64
# dtype: object

# %%
### Basic Data Visualization:


# Create a histogram to visualize the distribution of salaries
plt.figure(figsize=(10, 6))
plt.hist(df['TotalPay'], bins=20, edgecolor='black', alpha=0.7)
plt.title('Distribution of Salaries')
plt.xlabel('Total Pay')
plt.ylabel('Frequency')
plt.show()

# Use a bar chart to represent the top job titles
top_job_titles = df['JobTitle'].value_counts().head(10)
plt.figure(figsize=(10, 6))
top_job_titles.plot(kind='bar')
plt.title('Top 10 Job Titles')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.show()

# %%
### Descriptive Statistics:

# Calculate basic statistics
mean_salary = df['TotalPay'].mean()
median_salary = df['TotalPay'].median()
mode_salary = df['TotalPay'].mode()[0]
min_salary = df['TotalPay'].min()
max_salary = df['TotalPay'].max()
salary_range = max_salary - min_salary
std_salary = df['TotalPay'].std()

print("\nBasic Statistics:")
print(f"Mean Salary: {mean_salary}")
print(f"Median Salary: {median_salary}")
print(f"Mode Salary: {mode_salary}")
print(f"Minimum Salary: {min_salary}")
print(f"Maximum Salary: {max_salary}")
print(f"Salary Range: {salary_range}")
print(f"Standard Deviation of Salaries: {std_salary}")
# Out:
# Basic Statistics:
# Mean Salary: 74768.32197169267
# Median Salary: 71426.60999999999
# Mode Salary: 0.0
# Minimum Salary: -618.13
# Maximum Salary: 567595.43
# Salary Range: 568213.56
# Standard Deviation of Salaries: 50517.00527394987

# %%
# Check for missing values in each column
missing_values = df.isnull().sum()
print("\nMissing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
### Data Cleaning:

# Fill missing values in with the median
# Identify and handle missing values in specified columns
columns_with_missing_values = ['BasePay', 'OvertimePay', 'OtherPay', 'Benefits']

# Fill missing values in selected columns with the median
df[columns_with_missing_values] = df[columns_with_missing_values].fillna(df[columns_with_missing_values].median())

# For 'Notes' and 'Status', fill missing values with appropriate values or drop the columns if needed
# Filling 'Notes' with a placeholder value (you may choose a different approach based on your data)
df['Notes'].fillna('No notes available', inplace=True)

# Filling 'Status' with a placeholder value (you may choose a different approach based on your data)
df['Status'].fillna('Unknown', inplace=True)

# %%
### Basic Data Visualization:


# Create a histogram to visualize the distribution of salaries
plt.figure(figsize=(10, 6))
plt.hist(df['TotalPay'], bins=20, edgecolor='black', alpha=0.7)
plt.title('Distribution of Salaries')
plt.xlabel('Total Pay')
plt.ylabel('Frequency')
plt.show()

# Use a bar chart to represent the top job titles
top_job_titles = df['JobTitle'].value_counts().head(10)
plt.figure(figsize=(10, 6))
top_job_titles.plot(kind='bar')
plt.title('Top 10 Job Titles')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.show()

# %%
### Grouped Analysis:

# Group the data by department and calculate average salaries
average_salary_by_department = df.groupby('JobTitle')['TotalPay'].mean()

# Compare the average salaries across different departments
print("\nAverage Salaries by Job Title:")
print(average_salary_by_department)

### Simple Correlation Analysis:

# Identify any correlation between salary and another numerical column (e.g., 'BasePay')
correlation = df['TotalPay'].corr(df['BasePay'])

# Plot a scatter plot to visualize the relationship
plt.figure(figsize=(10, 6))
plt.scatter(df['BasePay'], df['TotalPay'])
plt.title('Scatter Plot of TotalPay vs. BasePay')
plt.xlabel('Base Pay')
plt.ylabel('Total Pay')
plt.show()

print("\nCorrelation between TotalPay and BasePay:", correlation)
# Out:
# Average Salaries by Job Title:
# JobTitle
# ACCOUNT CLERK                                     44035.664337
# ACCOUNTANT                                        47429.268000
# ACCOUNTANT INTERN                                 29031.742917
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     67594.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             52705.880385
# X-Ray Laboratory Aide                             50823.942700
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    53632.870000
# Youth Comm Advisor                                41414.307500
# ZOO CURATOR                                       66686.560000
# Name: TotalPay, Length: 2159, dtype: float64
# Correlation between TotalPay and BasePay: 0.9506887197970231

# %% [markdown]
# **Summary of Insights:**
#
# 1. **Dataset Overview:**
#    - The dataset contains information about employees, including their names, job titles, salary components (BasePay, OvertimePay, OtherPay), benefits, and total compensation.
#    - There are a total of [number of rows] rows and [number of columns] columns.
#
# 2. **Descriptive Statistics:**
#    - The average salary (TotalPay) is approximately [mean_salary], with a median of [median_salary], and a mode of [mode_salary]. This indicates [insight into the central tendency].
#    - Salaries range from [min_salary] to [max_salary], resulting in a salary range of [salary_range].
#    - The standard deviation of salaries is [std_salary], suggesting [insight into the variability].
#
# 3. **Data Cleaning:**
#   Identify and Handle Missing Values:
#
# The list columns_with_missing_values specifies the columns where missing values need attention. These columns are 'BasePay', 'OvertimePay', 'OtherPay', and 'Benefits'.
# Fill Missing Values with the Median:
#
# The code uses the fillna method to replace missing values in the specified columns ('BasePay', 'OvertimePay', 'OtherPay', 'Benefits') with the median of each respective column.
# Handling 'Notes' and 'Status':
#
# For 'Notes' and 'Status', missing values are filled with placeholder values. The 'Notes' column is filled with the placeholder value 'No notes available', and the 'Status' column is filled with 'Unknown'. Alternatively, you may choose a different approach based on the nature of your data.
#
# 4. **Basic Data Visualization:**
#    - The histogram of salaries illustrates a [skewness/normal distribution] in the salary distribution, providing insights into the concentration of salaries.
#    - The bar chart of the top 10 job titles reveals that [top job titles] are most prevalent in the organization.
#
# 5. **Grouped Analysis:**
#    - After grouping the data by job title, the average salaries for each job title were calculated. This analysis highlighted variations in salaries across different job titles, with [notable insights].
#
# 6. **Simple Correlation Analysis:**
#    - A scatter plot was used to visualize the relationship between 'TotalPay' and 'BasePay'. The correlation coefficient of [correlation] suggests [strength and direction of the correlation].
#
# 7. **Overall Insights:**
#    - The organization's salary structure is diverse, reflecting variations in job roles and responsibilities.
#    - Certain job titles have higher average salaries, indicating potential areas for talent retention or recruitment focus.
#    - The correlation analysis provides insights into the relationship between base pay and total pay, indicating [additional insights if any].
#
# This summary offers a comprehensive understanding of the dataset, its key statistics, insights into the salary distribution, and relationships between variables. Further exploration and analysis could delve into specific departments, years, or other relevant factors for a more detailed understanding.

# %% [markdown]
# # Good Luck!
